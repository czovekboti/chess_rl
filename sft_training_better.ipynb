# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
import os
os.environ["UNSLOTH_VLLM_STANDBY"] = "1" # [NEW] Extra 30% context lengths!
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install or uv pip install
    # !pip install unsloth vllm
else:
    pass # For Colab / Kaggle, we need extra instructions hidden below \/

# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
# !pip install python-chess
# !apt-get install stockfish

# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
import os
# !pip install --upgrade -qqq uv
if "COLAB_" not in "".join(os.environ.keys()):
    # If you're not in Colab, just use pip install!
    # !pip install unsloth vllm
else:
    try: import numpy, PIL; get_numpy = f"numpy=={numpy.__version__}"; get_pil = f"pillow=={PIL.__version__}"
    except: get_numpy = "numpy"; get_pil = "pillow"
    try: import subprocess; is_t4 = "Tesla T4" in str(subprocess.check_output(["nvidia-smi"]))
    except: is_t4 = False
    get_vllm, get_triton = ("vllm==0.9.2", "triton==3.2.0") if is_t4 else ("vllm==0.10.2", "triton")
    # !uv pip install -qqq --upgrade \
        unsloth {get_vllm} {get_numpy} {get_pil} torchvision bitsandbytes xformers
    # !uv pip install -qqq {get_triton}
# !uv pip install transformers==4.56.2
# !uv pip install --no-deps trl==0.22.2

# %%
#@title Load model config{ display-mode: "form" }
import os
from dotenv import load_dotenv
load_dotenv()

import yaml

# Path to your YAML config file
path = '/content/config.yaml'

def load_config(path: str):
    with open(path, 'r') as file:
        config = yaml.safe_load(file)
    return config

config = load_config(path)
config_name = "qwen4b"
print("Selected config_name:", config_name)

match config_name:
    case "llama":
        config = config["llama_config"]
    case "phi":
        config = config["PHI_config"]
    case "mistral":
        config = config["mistral_config"]
    case "qwen7b":
        config = config["qwen7b_config"]
    case "qwen4b":
        config = config["qwen4b_config"]
    case _:
        raise ValueError("Check model name – perhaps the keyboard got excited.")

# Stockfish path from env
# stockfish_path = os.getenv("STOCKFISH_PATH")
stockfish_path= '/usr/games/stockfish'

print("STOCKFISH_PATH:", stockfish_path)
# Out:
# Selected config_name: qwen4b
# STOCKFISH_PATH: /usr/games/stockfish

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 1024 # Can increase for longer reasoning traces
lora_rank = 32 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = config["model"],
    max_seq_length = max_seq_length,
    load_in_4bit = False, # False for LoRA 16bit
    fast_inference = False, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.7, # Reduce if out of memory
)
#add paddings
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token or "<|pad|>"

model.resize_token_embeddings(len(tokenizer))

target_modules = [
    "q_proj","k_proj","v_proj","o_proj",
    "gate_proj","up_proj","down_proj",

]
model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = target_modules,
    lora_alpha = lora_rank, # *2 speeds up training
    use_gradient_checkpointing = "unsloth", # Reduces memory usage
    random_state = 3407,
)
# Out:
# ==((====))==  Unsloth 2025.10.12: Fast Qwen3 patching. Transformers: 4.56.2. vLLM: 0.9.2.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.30. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Unsloth 2025.10.12 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %%
from sklearn.model_selection import train_test_split
from datasets import load_dataset
original_dataset = load_dataset("czovekboti/sft_chess", split="train")
split = original_dataset.train_test_split(test_size=30, seed=42)
train_ds = split["train"]
test_ds = split["test"]
print(train_ds)
print(test_ds)
# Out:
# Generating train split:   0%|          | 0/100 [00:00<?, ? examples/s]
# Dataset({
#     features: ['fen', 'top_5_moves', 'answer'],
#     num_rows: 70
# })
# Dataset({
#     features: ['fen', 'top_5_moves', 'answer'],
#     num_rows: 30
# })

# %%
SYSTEM_PROMPT = """You are a chess coach assistant. You will be given a board position in FEN format. Your job is to analyze the board and suggest the best legal move for the player whose turn it is.

Please follow this exact format in your response:

<reasoning>
(Brief explanation of what you see on the board — piece activity, threats, and candidate moves)
</reasoning>
<answer>
(best move written in correct SAN format, such as Nf3 or exd5)
</answer>

Do not invent illegal or impossible moves. The move must be legal in the given FEN position.
Do not use UCI format like e2e4 — only SAN notation like e4, Nf3, or O-O.
In case of taking a piece use the [file]x[target square] format
### Example:
FEN: rnbqkbnr/pppppppp/8/8/4P3/5N2/PPPP1PPP/RNBQKB1R b KQkq - 1 1

<reasoning>
White has just played e4 and developed the knight to f3. It’s Black’s turn. The e4 pawn is undefended. Capturing it with the pawn from d7 to d5 is a natural central counter.
</reasoning>
<answer>
d5
</answer>

Now solve the following position:
"""

def fen_color(fen: str) -> str:
    try:
        parts = fen.strip().split()
        side = parts[1]
        return "White" if side == "w" else "Black" if side == "b" else "Unknown"
    except Exception:
        return "Unknown"

# ---------- add this block after loading model/tokenizer ----------
import torch, re, pandas as pd
from datasets import load_dataset

# (optional but recommended) ensure a chat template is set for base models
try:
    from unsloth.chat_templates import get_chat_template
    if getattr(tokenizer, "chat_template", None) in (None, ""):
        tokenizer = get_chat_template(tokenizer, chat_template="qwen3")
except Exception:
    # fallback: minimal qwen-like template
    if getattr(tokenizer, "chat_template", None) in (None, ""):
        tokenizer.chat_template = (
            "{% for m in messages %}"
            "{% if m['role'] == 'system' %}<|im_start|>system\n{{ m['content'] }}<|im_end|>\n"
            "{% elif m['role'] == 'user' %}<|im_start|>user\n{{ m['content'] }}<|im_end|>\n"
            "{% elif m['role'] == 'assistant' %}<|im_start|>assistant\n{{ m['content'] }}<|im_end|>\n"
            "{% endif %}{% endfor %}{% if add_generation_prompt %}<|im_start|>assistant\n{% endif %}"
        )

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
model.to(DEVICE)
if tokenizer.pad_token_id is None:
    tokenizer.pad_token = tokenizer.eos_token



def extract_move(text: str):
    m = ANSWER_RE.search(text or "")
    return m.group(1).strip() if m else None

def to_top5_set(v):
    if v is None:
        return set()
    if isinstance(v, (list, tuple, set)):
        return set(str(x).strip() for x in v if str(x).strip())
    parts = [p.strip() for p in str(v).replace(";", ",").split(",")]
    return set(p for p in parts if p)

def build_prompt(fen: str, color: str):
    msgs = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": f"FEN: {fen}\nYou are with the following pieces: {color}"},
    ]
    return tokenizer.apply_chat_template(msgs, tokenize=False, add_generation_prompt=True)

def generate_answer(the_model, prompt: str, max_new_tokens=128, temperature=0.7, top_p=0.9, top_k=50):
    the_model.eval()
    with torch.no_grad():
        inputs = tokenizer(prompt, return_tensors="pt").to(DEVICE)
        out = the_model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=temperature > 0,
            temperature=temperature,
            top_p=top_p,
            top_k=top_k,
            pad_token_id=tokenizer.pad_token_id,
            eos_token_id=tokenizer.eos_token_id,
            use_cache=True,
        )
    gen_ids = out[0][inputs["input_ids"].shape[-1]:]
    return tokenizer.decode(gen_ids, skip_special_tokens=False)


print("=" * 80)
print("TESTING MODEL BEFORE TRAINING + SCORING")
print("=" * 80)

ANSWER_RE = re.compile(r"<answer>\s*(.*?)\s*</answer>", re.DOTALL | re.IGNORECASE)
REASONING_RE = re.compile(r"<reasoning>\s*(.*?)\s*</reasoning>", re.DOTALL | re.IGNORECASE)

def test_model(train_ds, model,answer_re,reasoning_re):
  i=0
  rows = []
  for example in train_ds:
        fen = example["fen"]
        color = fen_color(fen)
        prompt = build_prompt(fen, color)
        output = generate_answer(model, prompt, max_new_tokens=128, temperature=0.0, top_p=1.0, top_k=0)  # deterministic

        move = extract_move(output)
        has_reasoning = bool(REASONING_RE.search(output))
        has_answer_tag = bool(ANSWER_RE.search(output))

        top5 = to_top5_set(example.get("top_5_moves"))
        in_top5 = (move in top5) if move else False

        best_move = (example.get("best_move") or "").strip() or None
        equals_best = (move == best_move) if (move and best_move) else False

        score = 0
        score += 1 if has_reasoning else 0
        score += 1 if has_answer_tag else 0
        score += 1 if move else 0
        score += 2 if in_top5 else 0
        score += 2 if equals_best else 0

        print(f"\n{'='*80}")
        print(f"Example {i+1}/{len(train_ds)}")
        print(f"{'='*80}")
        print(f"FEN: {fen}")
        print(f"Color: {color}")
        print(f"\nGenerated Answer:\n{output}")

        rows.append({
            "idx": i,
            "FEN": fen,
            "Color": color,
            "Move": move or "",
            "HasReasoningTag": has_reasoning,
            "HasAnswerTag": has_answer_tag,
            "InTop5": in_top5,
            "EqualsBest": equals_best,
            "Score": score,
            "Top5Moves": ", ".join(sorted(top5)) if top5 else "",
            "BestMove": best_move or "",
            "RawOutput": output,
        })
        i+=1
  return rows

rows = test_model(test_ds, model,ANSWER_RE,REASONING_RE)
df = pd.DataFrame(rows).sort_values("Score", ascending=False).reset_index(drop=True)
print("\n=== SCORE TABLE (top 10 rows) ===")
print(df[["idx","Move","InTop5","EqualsBest","HasReasoningTag","HasAnswerTag","Score"]].head(50))

# save
df.to_csv("sft_answer_scoring_before_training.csv", index=False)
print("\nSaved: sft_answer_scoring_before_training.csv")
print("\nStarting training...\n")
# Out:
# ================================================================================
# TESTING MODEL BEFORE TRAINING + SCORING
# ================================================================================
#
# ================================================================================
# Example 1/30
# ================================================================================
# FEN: 7k/p1r2b2/4pq2/1p1p1nR1/5P2/P2B4/1P2Q2P/1K4R1 w - - 3 31
# Color: White
#
# Generated Answer:
# <reasoning>
# The position is with White to move. The key elements are: Black has a strong king-side presence with a rook on the 8th rank and a king on the 8th file (a1), and White has a queen, several pawns, and a bishop on the queenside. The white king is on d8, and the white queen is on c7. The central pawns are on d5 and e5, and there is a knight on f6. The black queen is on d6, and the black bishop is on c8. White has a strong initiative on the queens
#
# ================================================================================
# Example 2/30
# ================================================================================
# FEN: r1b1k2r/pp1n2pp/1qn1p3/3pp3/1b1P1P2/3B1N2/PP1BN1PP/R2QK2R w KQkq - 0 12
# Color: White
#
# Generated Answer:
# <reasoning>
# The position is with White to move. The white king is on e1, and the queen is on d4. There are pawns on the queenside and center, with a bishop on c5 and a knight on f6. The black pieces include a rook on a8, a knight on c8, and a bishop on b7. White has a strong central presence and a queen on d4, which is well-placed to support central pawns or to attack the dark squares. The most immediate threat is the potential for a queen to target the black king, which is on e8.
#
# ================================================================================
# Example 3/30
# ================================================================================
# FEN: 2r4k/p4bR1/3npq2/1p1p4/5P2/P2B4/1P2Q2P/1K4R1 b - - 0 29
# Color: Black
#
# Generated Answer:
# <reasoning>
# The position is with Black to move. The black king is on d8, and the rook on a8 and h8 are on the back rank. There is a black bishop on c5, and a black queen on d6. White has a pawn on e5 and a pawn on f4, and a bishop on b7. The black pieces are somewhat active, especially the bishop on c5 and the queen on d6, which control key central squares. The white pawn on e5 is under pressure — it is supported by the bishop on b7 and the queen on d6, which can
#
# ================================================================================
# Example 4/30
# ================================================================================
# FEN: r1bqk2r/pp1n2pp/2n1pp2/3pP3/1b1P1P2/3B1N2/PP1B2PP/R2QK1NR b KQkq - 3 10
# Color: Black
#
# Generated Answer:
# <reasoning>
# The position is with Black to move. The board shows a solid central pawn structure with Black having a strong presence on the queenside and center. Key elements include:
#
# - Black has a bishop on c8, a knight on d8, and a bishop on b7, suggesting active piece coordination.
# - White has a pawn on d4 and e4, and a bishop on c5, indicating central control.
# - Black’s queen is on a8, and the king is on d8 — a typical setup for a king-side attack.
# - The most immediate threat is the central pawn on d4, which is
#
# ================================================================================
# Example 5/30
# ================================================================================
# FEN: r1b3k1/pp2b1pp/4p3/3pn3/3q4/P2B1P2/1PQB3P/2KR3R w - - 0 18
# Color: White
#
# Generated Answer:
# <reasoning>
# White has a strong central presence with pawns on d4, e4, and f4, and a bishop on c5. The queen is on d5, and the bishop on b1 is active. Black has a rook on h8 and a king on e8. White’s king is on e1, and the position is slightly unbalanced. The key idea is to develop pieces and prepare a central attack. The most immediate threat is the queen on d5, which controls the center and threatens to push to e6 or f6. A natural move is to develop the bishop to c5
#
# ================================================================================
# Example 6/30
# ================================================================================
# FEN: r1b4k/pp4pB/4pB2/3p4/2n2P1q/P7/1PQ4P/1K1R3R b - - 0 22
# Color: Black
#
# Generated Answer:
# <reasoning>
# The position is with Black to move. The key elements are: Black has a queen on d8, a rook on a8, and a knight on c8. White has a pawn on d5, a queen on d4, and a rook on h1. The black king is on c8, and the white king is on a1. The black side is slightly better in development and has a strong rook on a8 and a queen on d8. However, the white queen on d4 is active and threatens to push the pawn on d5 or attack the black king. The
#
# ================================================================================
# Example 7/30
# ================================================================================
# FEN: r3b2k/p5p1/4pq2/1p1p4/2n2P2/P2B4/1P2Q2P/1K2R1R1 b - - 5 26
# Color: Black
#
# Generated Answer:
# <reasoning>
# The position is with Black to move. The key elements are: Black has a rook on a8, a queen on d8, and a king on c8. White has a queen on d4, a bishop on c5, and pawns on the queenside and center. Black’s king is on c8, which is a bit exposed, and the rook on a8 is active. The central pawns are weak, especially the e4 and d5 pawns. Black has a strong presence on the queenside with pawns on b5 and c6. The most immediate threat is
#
# ================================================================================
# Example 8/30
# ================================================================================
# FEN: r1b3k1/pp1nb1pp/1qn1p3/3pP3/3P4/P2B1r2/1PQBN1PP/R3K2R w KQ - 0 15
# Color: White
#
# Generated Answer:
# <reasoning>
# The position is with White to move. The king is on e8, and the queen is on d1, suggesting a strong central presence. White has a bishop on c5 and a knight on f3, and the pawns are advanced on the queenside and center. The key weakness is on the d-file: the d5 pawn is missing, and the e4 pawn is supported by the knight on f3. The black queen is on c8, and the black bishop on c7 is active. White has a strong initiative with the queen and bishops. A natural move is to develop the queen to
#
# ================================================================================
# Example 9/30
# ================================================================================
# FEN: r3k2r/1b3ppp/pq2pn2/2b3B1/Pp6/3B1N1P/1PP1QPP1/R4RK1 b kq - 2 18
# Color: Black
#
# Generated Answer:
# <reasoning>
# The position is with Black to move. The black king is on e8, and the rook on h8 is on the back rank. Black has a strong bishop on c8 and another on b7, supporting central and queenside activity. The white queen is on d5, and there are several white pieces on the queenside and center. The key point is that White has a strong central presence with pawns on d5, e4, and f4, and the bishop on c4. Black’s bishop on b7 and the one on c8 are active and may be targeting the white queen
#
# ================================================================================
# Example 10/30
# ================================================================================
# FEN: rnb1kb1r/pp3ppp/3qpn2/8/2Bp4/5N2/PPPN1PPP/R1BQ1RK1 w kq - 4 8
# Color: White
#
# Generated Answer:
# <reasoning>
# White has a bishop on b1, a knight on c1, and a queen on d8. The position shows Black has a queen on c3 and a knight on e5. White’s pieces are somewhat passive, but the key idea is to develop and centralize. The bishop on b1 is not active and is on the edge. The knight on c1 is also undeveloped. The most immediate threat is the central pawn structure — Black has a pawn on d6 and e5, and White has pawns on d4 and e4. The e4 pawn is under pressure from the knight
#
# ================================================================================
# Example 11/30
# ================================================================================
# FEN: rnbqkbnr/pppp1ppp/4p3/8/3PP3/8/PPP2PPP/RNBQKBNR b KQkq - 0 2
# Color: Black
#
# Generated Answer:
# <reasoning>
# The FEN shows a standard chess position with Black to move. The board has a pawn structure where White has pawns on the c-file and d-file in the center, and Black has a strong pawn chain on the c-file and d-file as well. The key point is that White has a central pawn chain with pawns on d4, e4, and f4, and Black has pawns on d5, e5, and f5. The center is tightly contested. Black has a strong central presence and can aim to push the d-pawn to d4 or e5 to gain space.
#
# ================================================================================
# Example 12/30
# ================================================================================
# FEN: r1b2rk1/pp1nb1pp/1qn1p3/3pP3/3P4/P2B1N2/1P1BN1PP/R2QK2R w KQ - 1 14
# Color: White
#
# Generated Answer:
# <reasoning>
# The position is with White to move. The white king is on e1, and the queen is on d4. There is a pawn on c7, d6, and e5, and a bishop on c5. The black king is on d8, and the rooks are on a8 and h8. White has a strong central presence with pawns on c4, d4, and e5. The bishop on c5 is active and controls key diagonals. The white queen on d4 is well-placed and can support central pawns or prepare a kingside attack. A key
#
# ================================================================================
# Example 13/30
# ================================================================================
# FEN: r1b2rk1/pp1n2pp/1qn1p3/3pP3/1b1P4/P2B1N2/1P1BN1PP/R2QK2R b KQ - 0 13
# Color: Black
#
# Generated Answer:
# <reasoning>
# The position is with Black to move. The board shows a solid central presence with Black's rooks on the back rank and a queen on c5. White has a pawn on d4 and a bishop on d3, and Black has a bishop on b1 and a knight on e5. The key point is that White's bishop on d3 is under pressure and may be vulnerable to attack. Black has a strong central pawn structure and a well-placed queen on c5, which can target the d4 pawn or the e4 square. The most immediate threat is to exploit the exposed d4 pawn.
#
# ================================================================================
# Example 14/30
# ================================================================================
# FEN: r6k/p4bp1/4pq2/1p1p4/2n2P2/P2B2R1/1P2Q2P/1K2R3 b - - 7 27
# Color: Black
#
# Generated Answer:
# <reasoning>
# Black to move. The position shows a strong central presence with a rook on the 7th rank and a queen on the 6th. White has a pawn on d5 and e4, and the black king is on c8. Black has a rook on a8 and another on d8, and a bishop on c7. The white queen is on d4, and the black queen is on d6. The key point is that White has a pawn on d5 and e4, and the black king is on c8, which is not in check. Black has a strong ro
#
# ================================================================================
# Example 15/30
# ================================================================================
# FEN: r3kb1r/1b3ppp/p2qpn2/1p6/8/3B1N2/PPP2PPP/R1BQ1RK1 w kq - 2 13
# Color: White
#
# Generated Answer:
# <reasoning>
# The position is with White to move. The white king is on e1, and the rooks are on a1 and h1. The bishop on c1 is active, and there is a light-squared bishop on d3. The black queen is on d8, and the black bishop on c8 is on the long diagonal. White has a central pawn structure with pawns on d4, e4, f4, and g4, and the light-squared bishop on d3 supports the center. The black king is on e8, and the black queen is on d8, which is
#
# ================================================================================
# Example 16/30
# ================================================================================
# FEN: r3k2r/1b3ppp/p3p3/8/Pp6/3BPNnP/1PP3P1/R4RK1 w kq - 1 22
# Color: White
#
# Generated Answer:
# <reasoning>
# White has a strong central presence with pawns on d5, e5, and f5, and a bishop on c5. The black king is on d8, and the white king is on e1. White’s pieces are well-positioned for central control and potential king-side castling. The black bishop on b3 is active and threatens the e4 square. White’s pawns on d5 and e5 are supported by the bishop on c5, and the knight on f6 is a strong piece in the center. The most immediate threat is the potential for a pawn break on d4 or
#
# ================================================================================
# Example 17/30
# ================================================================================
# FEN: r6k/p4bp1/4pq2/1p1p4/2n2P2/P2B4/1P2Q2P/1K2R1R1 w - - 6 27
# Color: White
#
# Generated Answer:
# <reasoning>
# White has a knight on d5 and a bishop on c5, both active in the center. The black king is on c8, and the white king is on d8. White has a queen on d4 and a rook on h8. The black queen is on e7, and the black bishop is on b7. The white pawns are on the c-file and d-file, with a pawn on c3 and d4. The key weakness is the black king being exposed on c8, and the white pieces are well-placed to attack it. The most immediate threat is to deliver
#
# ================================================================================
# Example 18/30
# ================================================================================
# FEN: 7k/p1r2b2/5q2/1p1p1pR1/5P2/P7/1P2Q2P/1K4R1 w - - 0 32
# Color: White
#
# Generated Answer:
# <reasoning>
# The position is with White to move. The key elements are: Black has a strong king-side presence with a rook on the 8th rank and a queen on d5, while White has a queen on c4, a rook on h1, and pawns on the queenside and center. The white king is on e1, and the pawns on the queenside (especially on d5 and e5) are active. The black king is on d8, and the black rook on h8 is on the back rank. White’s queen on c4 is well-placed to
#
# ================================================================================
# Example 19/30
# ================================================================================
# FEN: rnbqkbnr/ppp2ppp/4p3/3p4/3PP3/8/PPPN1PPP/R1BQKBNR b KQkq - 1 3
# Color: Black
#
# Generated Answer:
# <reasoning>
# The position is with Black to move. The key feature is the presence of a white knight on d5 (PNN1PPP in the white king side), and a white pawn on d4. Black has a strong central presence with pawns on c5, d6, and e5. The white king is on e8, and the white pawns are advancing on the queenside and center. However, the most immediate threat is the white knight on d5, which is attacking the black king and potentially threatening a discovered attack or a pawn break. Black’s king is on e8, and the position
#
# ================================================================================
# Example 20/30
# ================================================================================
# FEN: r3k2r/1b3ppp/p3p3/7n/Pp6/3BqN1P/1PP2PP1/R4RK1 w kq - 0 21
# Color: White
#
# Generated Answer:
# <reasoning>
# White to move with a strong king-side presence. The position shows Black has a knight on f6 and a bishop on c8, and White has a bishop on b3, a queen on d4, and pawns on the queenside and center. The key weakness is the exposed king on the kingside, particularly the e8 square. White has a strong initiative with the bishop on b3 and the queen on d4. The most immediate threat is to exploit the weak e8 square and prepare a kingside attack. A natural and forcing move is to play Qe4, which attacks the knight on
#
# ================================================================================
# Example 21/30
# ================================================================================
# FEN: r3k2r/1b3ppp/pq2p3/2b4n/Pp6/3BBN1P/1PP1QPP1/R4RK1 b kq - 4 19
# Color: Black
#
# Generated Answer:
# <reasoning>
# The position is with Black to move. The board shows a strong central presence with Black pawns on the d-file and e-file, and several bishops and knights on the dark squares. Black has a queen on d8, and the king is on the back rank (e8). The white king is on d1, and the white queen is on c1. Black has a strong bishop on c8 and another on b7, and a knight on f6. The white pawns are on the queenside and center, with a pawn on d5 and e4. The key point is that White has
#
# ================================================================================
# Example 22/30
# ================================================================================
# FEN: r1b4k/pp2b1pB/4p3/3pn3/7q/P4P2/1PQB3P/1K1R3R w - - 3 20
# Color: White
#
# Generated Answer:
# <reasoning>
# The position is with White to move. The key elements are the weak black king side, the presence of a queen on d8, and a passive black rook on a8. White has a queen on b1, a bishop on c1, and a knight on d2. The black queen is on d8, threatening to attack the white pawns on the queenside. However, the most immediate threat is the white queen on b1, which is not yet developed. The white king is on e1, and the rook on e1 is not active. The pawns on the queenside
#
# ================================================================================
# Example 23/30
# ================================================================================
# FEN: r1b3k1/pp1nb1pp/1qn1p3/3pP3/3P4/P2B1P2/1PQBN2P/R3K2R b KQ - 0 15
# Color: Black
#
# Generated Answer:
# <reasoning>
# The position is with Black to move. The black king is on e8, and the rooks are on a8 and h8. White has a queen on q1, a bishop on c5, and a knight on b1. The key point is that White has a strong central presence with pawns on d4, e4, and f4, and a bishop on c5. Black’s pieces are somewhat passive, and the center is not fully controlled. However, Black has a strong rook on h8 and a queen on q1, which can support a potential attack on the king or
#
# ================================================================================
# Example 24/30
# ================================================================================
# FEN: r1b1kb1r/5ppp/p2qpn2/1p6/8/3B1N2/PPP2PPP/R1BQ1RK1 b kq - 1 12
# Color: Black
#
# Generated Answer:
# <reasoning>
# The position is with Black to move. The key elements are the isolated light-squared bishop on c5, the knight on d5, and the active White center with pawns on e4, d4, and c4. Black has a strong bishop on c8 and a queen on d8, but the central pawns are somewhat weak. The most immediate threat is the White bishop on b3, which controls the d4 square and threatens to push to c4 or d5. Black’s best move is to target the central weakness and prevent White from centralizing. The knight on d5 is already
#
# ================================================================================
# Example 25/30
# ================================================================================
# FEN: rnbqkb1r/pppn1ppp/4p3/3pP3/3P4/8/PPPN1PPP/R1BQKBNR w KQkq - 1 5
# Color: White
#
# Generated Answer:
# <reasoning>
# The position shows White to move with a strong central pawn structure and active pieces. White has pawns on d4, e4, and f4, with a potential center and queenside presence. The black king is on e8, and White’s king is on e1. The key point is that White has a pawn on d4 and e4, and the f4 pawn is supported by the knight on f3. The black queen is on d7, and the black bishop on c8 is active. White’s bishop on c1 is not yet developed, and the knight on f3 is well
#
# ================================================================================
# Example 26/30
# ================================================================================
# FEN: 2r4k/p4bR1/4pq2/1p1p1n2/5P2/P2B4/1P2Q2P/1K4R1 w - - 1 30
# Color: White
#
# Generated Answer:
# <reasoning>
# The position is with White to move. The key elements are: White has a queen on d4, a bishop on c5, and a knight on f3. Black has a rook on c8, a bishop on b7, and a queen on d8. White’s king is on a8, and the pawn structure is somewhat passive on the queenside. The most immediate threat is the queen on d4, which is well-placed to support central or kingside attacks. However, the black queen on d8 is active and may be targeting the white queen. The white bishop on c5
#
# ================================================================================
# Example 27/30
# ================================================================================
# FEN: r1b1kb1r/5ppp/p2qpn2/1p6/2B5/5N2/PPP2PPP/R1BQ1RK1 w kq - 0 12
# Color: White
#
# Generated Answer:
# <reasoning>
# The position is with White to move. The pawn structure shows a central pawn chain with White having pawns on the d-, e-, and f-files, and a strong bishop on the light squares. Black has a knight on c8 and a queen on c5, which is a strong central presence. White’s king is on e8, and the rook on a1 is not yet developed. The most immediate threat is the central control — Black’s queen on c5 is attacking the d4 and e4 squares, and the knight on c8 is poised to jump to d6 or f7. White
#
# ================================================================================
# Example 28/30
# ================================================================================
# FEN: r1b2rk1/pp1nb1pp/1qn1p3/3pP3/3P4/P2B1N2/1PQBN1PP/R3K2R b KQ - 2 14
# Color: Black
#
# Generated Answer:
# <reasoning>
# The position is with Black to move. The board shows a strong central presence with Black’s rooks on the back rank and a queen on c8. White has a pawn on d4 and e4, and the center is somewhat occupied. Black has a bishop on c8 and a knight on d7, and the queen is on c8. The key point is that White’s pawns on d4 and e4 are supported by a bishop on c5 and a knight on f3. Black’s queen is on c8, and the only immediate threat is to exploit the weak d4 and e4
#
# ================================================================================
# Example 29/30
# ================================================================================
# FEN: r1b1kb1r/pp3ppp/3qpn2/8/2BN4/8/PPP2PPP/R1BQ1RK1 b kq - 0 10
# Color: Black
#
# Generated Answer:
# <reasoning>
# Black to move with the pieces listed. The position shows White has a strong central presence with pawns on e4, d4, and c4, and a bishop on c5. Black has a queen on c7, a bishop on b8, and a knight on f8. The key point is that White’s bishop on c5 is active and threatens to target the black king. Black’s king is on a8, and the queen is on c7, which is a strong square. The most immediate threat is the potential for White to play Bc4 or Bb5, but Black can
#
# ================================================================================
# Example 30/30
# ================================================================================
# FEN: r1b1kb1r/1p3ppp/p2qpn2/8/2B5/5N2/PPP2PPP/R1BQ1RK1 b kq - 1 11
# Color: Black
#
# Generated Answer:
# <reasoning>
# The position is with Black to move. The key elements are the central pawns, the knight on e5, and the bishop on c5. White has a strong bishop on c5 and a knight on e5, both threatening central control. Black has a queen on d8 and a bishop on c8, but the most immediate threat is the knight on e5, which is attacking the d4 pawn and potentially preparing to push to d6 or f6. However, the most urgent defensive and offensive move for Black is to develop and support the center. The pawn on d7 is a key square —
#
# === SCORE TABLE (top 10 rows) ===
#     idx Move  InTop5  EqualsBest  HasReasoningTag  HasAnswerTag  Score
# 0     0        False       False            False         False      0
# 1     1        False       False            False         False      0
# 2     2        False       False            False         False      0
# 3     3        False       False            False         False      0
# 4     4        False       False            False         False      0
# 5     5        False       False            False         False      0
# 6     6        False       False            False         False      0
# 7     7        False       False            False         False      0
# 8     8        False       False            False         False      0
# 9     9        False       False            False         False      0
# 10   10        False       False            False         False      0
# 11   11        False       False            False         False      0
# 12   12        False       False            False         False      0
# 13   13        False       False            False         False      0
# 14   14        False       False            False         False      0
# 15   15        False       False            False         False      0
# 16   16        False       False            False         False      0
# 17   17        False       False            False         False      0
# 18   18        False       False            False         False      0
# 19   19        False       False            False         False      0
# 20   20        False       False            False         False      0
# 21   21        False       False            False         False      0
# 22   22        False       False            False         False      0
# 23   23        False       False            False         False      0
# 24   24        False       False            False         False      0
# 25   25        False       False            False         False      0
# 26   26        False       False            False         False      0
# 27   27        False       False            False         False      0
# 28   28        False       False            False         False      0
# 29   29        False       False            False         False      0
#
# Saved: sft_answer_scoring_before_training.csv
#
# Starting training...

# %%
# Toggle W&B logging (set to False if you don't want to log)
USE_WANDB = True

if USE_WANDB:
    import wandb
    os.environ["WANDB_LOG_MODEL"] = "end"

    os.environ["WANDB_PROJECT"] = "Chess_RL_Project"
    os.environ["WANDB_ENTITY"] = "czovekboti-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem"
    wandb.login()
    wandb.init(
        project="Chess_RL_Project",
        entity="",
        name=config.get("name", "run"),
        config={
            "model": config["model"],
            "max_seq_length": config['max_seq_length'],
            "lora_rank": lora_rank,
            "learning_rate": config["learning_rate"],
            "max_steps": config["max_steps"],
        }
    )
    print("W&B initialized.")
else:
    print("W&B disabled.")
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Currently logged in as: czovekboti (czovekboti-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251101_173944-fj2q225k</code>
# Syncing run <strong><a href='https://wandb.ai/czovekboti-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/Chess_RL_Project/runs/fj2q225k' target="_blank">qwen-4B</a></strong> to <a href='https://wandb.ai/czovekboti-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/Chess_RL_Project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/czovekboti-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/Chess_RL_Project' target="_blank">https://wandb.ai/czovekboti-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/Chess_RL_Project</a>
#  View run at <a href='https://wandb.ai/czovekboti-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/Chess_RL_Project/runs/fj2q225k' target="_blank">https://wandb.ai/czovekboti-budapesti-m-szaki-s-gazdas-gtudom-nyi-egyetem/Chess_RL_Project/runs/fj2q225k</a>
# wandb: Detected [huggingface_hub.inference, openai] in use.
# wandb: Use W&B Weave for improved LLM call tracing. Install Weave with `pip install weave` then add `import weave` to the top of your script.
# wandb: For more information, check out the docs at: https://weave-docs.wandb.ai/
# W&B initialized.

# %%
formatted_texts = []
from datasets import Dataset
print(train_ds)
for ex in train_ds:
    fen = (ex.get("fen") or "").strip()
    ans = (ex.get("answer") or "").strip()
    if not fen or not ans:
        continue
    color = fen_color(fen)
    messages = [
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": f"\nFEN: {fen}\nYou are with the following pieces: {color}"},
            {"role": "assistant", "content": ans},

    ]
    formatted_texts.append({"conversations": messages})
def formatting_prompts_func(examples):
    convos = examples["conversations"]
    texts = [tokenizer.apply_chat_template(convo, tokenize = False, add_generation_prompt = False) for convo in convos]
    return { "text" : texts, }
from datasets import Dataset
print(formatted_texts)
# formatted_texts is just a list of dicts
dataset = Dataset.from_list(formatted_texts)

dataset = dataset.map(formatting_prompts_func, batched = True,)
# Out:
# Dataset({
#     features: ['fen', 'top_5_moves', 'answer'],
#     num_rows: 70
# })
# [{'conversations': [{'role': 'system', 'content': 'You are a chess coach assistant. You will be given a board position in FEN format. Your job is to analyze the board and suggest the best legal move for the player whose turn it is.\n\nPlease follow this exact format in your response:\n\n<reasoning>\n(Brief explanation of what you see on the board — piece activity, threats, and candidate moves)\n</reasoning>\n<answer>\n(best move written in correct SAN format, such as Nf3 or exd5)\n</answer>\n\nDo not invent illegal or impossible moves. The move must be legal in the given FEN position.\nDo not use UCI format like e2e4 — only SAN notation like e4, Nf3, or O-O.\nIn case of taking a piece use the [file]x[target square] format\n### Example:\nFEN: rnbqkbnr/pppppppp/8/8/4P3/5N2/PPPP1PPP/RNBQKB1R b KQkq - 1 1\n\n<reasoning>\nWhite has just played e4 and developed the knight to f3. It’s Black’s turn. The e4 pawn is undefended. Capturing it with the pawn from d7 to d5 is a natural central counter.\n</reasoning>\n<answer>\nd5\n</answer>\n\nNow solve the following position:\n'}, {'role': 'user', 'content': '\nFEN: r1b4k/pp2b1pB/4p3/3pn3/7q/P1B2P2/1PQ4P/1K1R3R b - - 4 20\nYou are with the following pieces: Black'}, {'role': 'assistant', 'content': "<reasoning>\nf6 is a strong recapture that removes the queen from the board and reduces White's attack on the black king. It also prepares for future development of the queen or another piece.\n\nBf6 is a positional move that strengthens Black's kingside pawn structure and prepares to support potential advances with ...d5 in the near future. It also puts pressure on White's queen and restricts its mobility.\n\nHowever, f6 is objectively the best move because it significantly weakens White's position by removing a powerful attacking piece and reducing their ability to develop pieces effectively. This leads to a more favorable outcome for Black in the long term.\n</reasoning>\n<answer>\nf6\n</answer>"}]}, {'conversations': [{'role': 'system', 'content': 'You are a chess coach assistant. You will be given a board position in FEN format. Your job is to analyze the board and suggest the best legal move for the player whose turn it is.\n\nPlease follow this exact format in your response:\n\n<reasoning>\n(Brief explanation of what you see on the board — piece activity, threats, and candidate moves)\n</reasoning>\n<answer>\n(best move written in correct SAN format, such as Nf3 or exd5)\n</answer>\n\nDo not invent illegal or impossible moves. The move must be legal in the given FEN position.\nDo not use UCI format like e2e4 — only SAN notation like e4, Nf3, or O-O.\nIn case of taking a piece use the [file]x[target square] format\n### Example:\nFEN: rnbqkbnr/pppppppp/8/8/4P3/5N2/PPPP1PPP/RNBQKB1R b KQkq - 1 1\n\n<reasoning>\nWhite has just played e4 and developed the knight to f3. It’s Black’s turn. The e4 pawn is undefended. Capturing it with the pawn from d7 to d5 is a natural central counter.\n</reasoning>\n<answer>\nd5\n</answer>\n\nNow solve the following position:\n'}, {'role': 'user', 'content': '\nFEN: rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1\nYou are with the following pieces: Black'}, {'role': 'assistant', 'content': '<reasoning>\nc6 is a solid development move that advances the center pawns and prepares to open files for the queen. It also prevents White from easily recapturing on c5 with their queen. Other moves like Nc6 or Bb7 are either slower or less direct in developing the board. c6 is therefore the best move as it creates immediate pressure and positional advantage.\n</reasoning>\n<answer>\nc6\n</answer>'}]}, {'conversations': [{'role': 'system', 'content': 'You are a chess coach assistant. You will be given a board position in FEN format. Your job is to analyze the board and suggest the best legal move for the player whose turn it is.\n\nPlease follow this exact format in your response:\n\n<reasoning>\n(Brief explanation of what you see on the board — piece activity, t ...
# Map:   0%|          | 0/70 [00:00<?, ? examples/s]

# %%
from trl import SFTConfig, SFTTrainer
from transformers import DataCollatorForSeq2Seq
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    data_collator = DataCollatorForSeq2Seq(tokenizer = tokenizer),
    packing = False, # Can make training 5x faster for short sequences.
    args = SFTConfig(
        completion_only_loss=True,
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        num_train_epochs = 5, # Set this for 1 full training run.
        max_steps = len(dataset)*5,
        learning_rate = 1e-3,
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "wandb", # Use TrackIO/WandB etc
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/70 [00:00<?, ? examples/s]

# %%
trainer.train()
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None}.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 70 | Num Epochs = 39 | Total steps = 350
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 66,060,288 of 4,087,844,864 (1.62% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='350' max='350' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [350/350 40:08, Epoch 38/39]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.697200</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.672100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.980900</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.544400</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.182900</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.851700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.632400</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.558500</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.479800</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.435700</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.406600</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.440000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.349100</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.516800</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.386600</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.435200</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.398900</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.425100</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.343700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.345300</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.327700</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.314600</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.304900</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.327000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.287300</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.274100</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.290000</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.254200</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.224600</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.208300</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.214200</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.195300</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.198600</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.202100</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.239400</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.213400</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.159900</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.156800</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.147700</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.132900</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.151800</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.161200</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.140500</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.157700</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.138900</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.106100</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.113100</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.092700</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.111000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.098900</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.107700</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.114000</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.118400</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.103900</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.077800</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.087500</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.094800</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.079300</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.075700</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.087500</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.092200</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.088800</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.105100</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.070700</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.059400</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.075700</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.073900</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.070700</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.074500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.076300</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.076100</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.074000</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.051800</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.053100</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.057500</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.057400</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.057100</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.061600</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.063100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.072600</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.083800</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.049400</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.050600</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.053000</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.066500</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.062400</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.069100</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.051900</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.058300</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.071300</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.044500</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0.042100</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>0.044000</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>0.054300</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.052400</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.057600</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.058700</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.057200</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.053100</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.042000</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.044200</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.046300</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.054600</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.046100</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.045600</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.043300</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.043200</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.043600</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.034600</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.038700</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0.039900</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.041100</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.046500</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>0.044200</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.042700</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.042000</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.059800</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>0.040100</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.036200</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.034800</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.038600</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>0.037300</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.041400</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.040300</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.041400</td>
#     </tr>
#     <tr>
#       <td>126<
# /usr/local/lib/python3.12/dist-packages/peft/utils/save_and_load.py:300: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/peft/utils/save_and_load.py:300: UserWarning: Setting `save_embedding_layers` to `True` as the embedding layer has been resized during finetuning.
#   warnings.warn(
# TrainOutput(global_step=350, training_loss=0.09355128367564508, metrics={'train_runtime': 2166.5516, 'train_samples_per_second': 1.292, 'train_steps_per_second': 0.162, 'total_flos': 2.967348449939251e+16, 'train_loss': 0.09355128367564508, 'epoch': 38.91428571428571})

# %%
trained_model = trainer.model

# %%
# for i in range(num_test_examples):
#     example = original_dataset[i]
#     fen = example["fen"]
#     color = fen_color(fen)

#     prompt = build_prompt(fen, color)
#     output = generate_answer(trained_model, prompt, max_new_tokens=128, temperature=0.0, top_p=1.0, top_k=0)  # deterministic

#     move = extract_move(output)
#     has_reasoning = bool(REASONING_RE.search(output))
#     has_answer_tag = bool(ANSWER_RE.search(output))

#     top5 = to_top5_set(example.get("top_5_moves"))
#     in_top5 = (move in top5) if move else False

#     best_move = (example.get("best_move") or "").strip() or None
#     equals_best = (move == best_move) if (move and best_move) else False
#     score = 0
#     score += 1 if has_reasoning else 0
#     score += 1 if has_answer_tag else 0
#     score += 1 if move else 0
#     score += 2 if in_top5 else 0
#     score += 2 if equals_best else 0

#     print(f"\n{'='*80}")
#     print(f"Example {i+1}/{num_test_examples}")
#     print(f"{'='*80}")
#     print(f"FEN: {fen}")
#     print(f"Color: {color}")
#     print(f"\nGenerated Answer:\n{output}")

#     rows.append({
#         "idx": i,
#         "FEN": fen,
#         "Color": color,
#         "Move": move or "",
#         "HasReasoningTag": has_reasoning,
#         "HasAnswerTag": has_answer_tag,
#         "InTop5": in_top5,
#         "EqualsBest": equals_best,
#         "Score": score,
#         "Top5Moves": ", ".join(sorted(top5)) if top5 else "",
#         "BestMove": best_move or "",
#         "RawOutput": output,
#     })
rows  = test_model(test_ds,trained_model,ANSWER_RE,REASONING_RE)
df = pd.DataFrame(rows).sort_values("Score", ascending=False).reset_index(drop=True)
print("\n=== SCORE TABLE (top 10 rows) ===")
print(df[["idx","Move","InTop5","EqualsBest","HasReasoningTag","HasAnswerTag","Score"]].head(50))
df.to_csv("sft_answer_scoring_after_training.csv", index=False)
# Out:
# ================================================================================
# Example 1/30
# ================================================================================
# FEN: 7k/p1r2b2/4pq2/1p1p1nR1/5P2/P2B4/1P2Q2P/1K4R1 w - - 3 31
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# g2 is a weak move as it fails to develop a piece effectively and does not provide immediate threats or positional advantages. It also allows the opponent to recapture on g2 without losing material.
#
# Rg2 is a strong move as it develops the rook to a powerful square and threatens to open up the center. This move puts pressure on the black king and prepares for future attacks.
#
# Therefore, Rg2 is the best move because it maximizes the potential of the rook and creates immediate threats.
# </reasoning>
# <answer>
# Rg2
# </answer><|im_end|>
#
# ================================================================================
# Example 2/30
# ================================================================================
# FEN: r1b1k2r/pp1n2pp/1qn1p3/3pp3/1b1P1P2/3B1N2/PP1BN1PP/R2QK2R w KQkq - 0 12
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# e2 is a weak move as it fails to develop a piece meaningfully and does not advance the pawn structure effectively.
#
# Ne2 is the best move as it develops a knight to a strong square (g5) and prepares to support the center with Qa5 later on.
# </reasoning>
# <answer>
# Ne2
# </answer><|im_end|>
#
# ================================================================================
# Example 3/30
# ================================================================================
# FEN: 2r4k/p4bR1/3npq2/1p1p4/5P2/P2B4/1P2Q2P/1K4R1 b - - 0 29
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# g8 is a forced recapture, removing the queen from the board and weakening Black's position by capturing on the king. This move immediately improves White's control over the center and reduces Black's counterplay options significantly. The key strength of g8 is that it maximizes White's advantage by simplifying the game and reducing Black's potential threats.
# </reasoning>
# <answer>
# g8
# </answer><|im_end|>
#
# ================================================================================
# Example 4/30
# ================================================================================
# FEN: r1bqk2r/pp1n2pp/2n1pp2/3pP3/1b1P1P2/3B1N2/PP1B2PP/R2QK1NR b KQkq - 3 10
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# O-O is the only candidate move, which is castling kingside. This move quickly strengthens the king's position on the backrank, improves the safety of the queen, and prepares to support the attack on the opponent's position. There are no other candidate moves to compare against, so there is no need for further analysis.
#
# O-O is the best move because it provides immediate tactical advantage and fortifies the king's position, making it difficult for the opponent to counter effectively.
# </reasoning>
# <answer>
# O-O
# </answer><|im_end|>
#
# ================================================================================
# Example 5/30
# ================================================================================
# FEN: r1b3k1/pp2b1pp/4p3/3pn3/3q4/P2B1P2/1PQB3P/2KR3R w - - 0 18
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# Kb1 brings the king to safety and prepares to castle kingside. This move avoids putting the king in immediate danger and positions it for castling, which can be crucial later in the game. Other moves like Nf3 or Ng5 involve developing pieces but do not address the immediate threat to the king as effectively.
#
# Kb1 is objectively the best move because it prioritizes king safety and prepares for a potential kingside castling, which is a fundamental defensive principle in chess.
# </reasoning>
# <answer>
# Kb1
# </answer><|im_end|>
#
# ================================================================================
# Example 6/30
# ================================================================================
# FEN: r1b4k/pp4pB/4pB2/3p4/2n2P1q/P7/1PQ4P/1K1R3R b - - 0 22
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# d7 captures a piece on e5, applying pressure on black's position and potentially opening up further possibilities for the queen.
# Bd7 recaptures with the bishop but does not immediately resolve threats and might allow black to regroup more effectively.
#
# Therefore, d7 is best because it immediately removes a threat and gains material, putting pressure on black's position.
# </reasoning>
# <answer>
# d7
# </answer><|im_end|>
#
# ================================================================================
# Example 7/30
# ================================================================================
# FEN: r3b2k/p5p1/4pq2/1p1p4/2n2P2/P2B4/1P2Q2P/1K2R1R1 b - - 5 26
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# g8 is a forced recapture, removing the queen from the board and weakening Black's position by capturing on the king. This move immediately improves White's control over the center and reduces Black's counterplay options significantly. The key strength of g8 is that it maximizes White's advantage by simplifying the game and reducing Black's potential threats.
# </reasoning>
# <answer>
# g8
# </answer><|im_end|>
#
# ================================================================================
# Example 8/30
# ================================================================================
# FEN: r1b3k1/pp1nb1pp/1qn1p3/3pP3/3P4/P2B1r2/1PQBN1PP/R3K2R w KQ - 0 15
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# Nxd4 is a powerful recapture that eliminates a dangerous queen pawn and gains tempo by developing a knight.
# xd5 would be a passive move, simply trading off pieces without creating threats.
# Qxd4 would sacrifice too much material for little gain.
# In contrast, Nxd4 immediately strengthens White's position by capturing on the diagonal and threatening further advances.
# </reasoning>
# <answer>
# Nxd4
# </answer><|im_end|>
#
# ================================================================================
# Example 9/30
# ================================================================================
# FEN: r3k2r/1b3ppp/pq2pn2/2b3B1/Pp6/3B1N1P/1PP1QPP1/R4RK1 b kq - 2 18
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# c5 is a strong move that attacks the white queen and threatens to recapture on e4. It also puts pressure on the white king's position. However, it sacrifices the knight, which could be considered weak if White manages to defend well.
#
# Bc5 is a more balanced move. It develops the bishop to a strong square and prepares to support the queen on the kingside. This move maintains development while controlling key squares on both wings.
#
# Therefore, Bc5 is objectively the best move because it combines effective piece development with tactical threats, providing a stronger overall position for Black.
# </reason
#
# ================================================================================
# Example 10/30
# ================================================================================
# FEN: rnb1kb1r/pp3ppp/3qpn2/8/2Bp4/5N2/PPPN1PPP/R1BQ1RK1 w kq - 4 8
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# Nxd4 captures an important piece and advances the queen towards the center, putting pressure on black's king.
# xc6 would be a premature recapture that gives away control of the center.
# exd4 loses material without immediate threats.
# The best move is Nxd4 because it effectively counters black's central development and prepares to challenge their position.
# </reasoning>
# <answer>
# Nxd4
# </answer><|im_end|>
#
# ================================================================================
# Example 11/30
# ================================================================================
# FEN: rnbqkbnr/pppp1ppp/4p3/8/3PP3/8/PPP2PPP/RNBQKBNR b KQkq - 0 2
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# c6 is a solid development move that advances the center pawns and prepares to open files for the queen. It also prevents White from easily recapturing on c5 with their queen. Other moves like Nc6 or Bb7 are either slower or less direct in developing the board. c6 is therefore the best move as it creates immediate pressure and positional advantage.
# </reasoning>
# <answer>
# c6
# </answer><|im_end|>
#
# ================================================================================
# Example 12/30
# ================================================================================
# FEN: r1b2rk1/pp1nb1pp/1qn1p3/3pP3/3P4/P2B1N2/1P1BN1PP/R2QK2R w KQ - 1 14
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# c3 weakens black's position slightly by pushing the queen back and not developing a piece effectively.
# Bc3 improves White's bishops' squares, enhances their mobility, and prepares to recapture on g5 with greater pressure.
# Both moves have merit, but Bc3 offers more immediate strategic advantage by supporting the development of other pieces and creating potential threats.
# </reasoning>
# <answer>
# Bc3
# </answer><|im_end|>
#
# ================================================================================
# Example 13/30
# ================================================================================
# FEN: r1b2rk1/pp1n2pp/1qn1p3/3pP3/1b1P4/P2B1N2/1P1BN1PP/R2QK2R b KQ - 0 13
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# c6 advances the pawns on the queenside and prepares to develop the queen to a strong square. However, it doesn't immediately threaten any material gain or significant positional advantage.
#
# Nc6 recaptures on the queen with a piece that can later be developed and supports a potential queen sacrifice if needed. This move also creates pressure on the white king and could lead to a favorable knight structure.
#
# Therefore, Nc6 is objectively the best move because it targets both pieces and positions well for future development while putting pressure on the white king.
# </reasoning>
# <answer>
# Nc6
#
# ================================================================================
# Example 14/30
# ================================================================================
# FEN: r6k/p4bp1/4pq2/1p1p4/2n2P2/P2B2R1/1P2Q2P/1K2R3 b - - 7 27
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# e8 captures the opponent's queen, resulting in a significant material gain. This move is strong because it maximizes the material advantage and ends the game quickly. The other moves like Nf3, Bb5, and Bh6 do not provide immediate threats or gains.
# </reasoning>
# <answer>
# e8
# </answer><|im_end|>
#
# ================================================================================
# Example 15/30
# ================================================================================
# FEN: r3kb1r/1b3ppp/p2qpn2/1p6/8/3B1N2/PPP2PPP/R1BQ1RK1 w kq - 2 13
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# e1 is a knight move to e1, which is not a standard move in chess. It does not develop a piece, control squares, or create threats. It is unlikely to be a good move given the current state of the board.
# Re1 is a rook move to e1, which is also an unusual move. It does not develop the rook effectively or create immediate threats. It is not a logical move in this context.
#
# Therefore, neither move is particularly strong or weak on their own. However, considering the need to develop pieces and control the center in chess, Re1
#
# ================================================================================
# Example 16/30
# ================================================================================
# FEN: r3k2r/1b3ppp/p3p3/8/Pp6/3BPNnP/1PP3P1/R4RK1 w kq - 1 22
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# a5 advances the queen and prepares to recapture on b5, controlling the center effectively. It also creates an open file for the rook.
# a4 is less direct and does not immediately control the center or prepare a strong recapture.
# a6 is slow and does not address the immediate threats to the white king.
# Therefore, a5 is best because it prepares a strong recapture on b5 and controls the center effectively.
# </reasoning>
# <answer>
# a5
# </answer><|im_end|>
#
# ================================================================================
# Example 17/30
# ================================================================================
# FEN: r6k/p4bp1/4pq2/1p1p4/2n2P2/P2B4/1P2Q2P/1K2R1R1 w - - 6 27
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# g2 is a weak move as it fails to develop a piece effectively and does not provide immediate threats or positional advantages. It also allows the opponent to recapture on g2 without losing material.
#
# Rg2 is a strong move as it develops the rook to a powerful square and threatens to open up the center. This move puts pressure on the black king and prepares for future attacks.
#
# Therefore, Rg2 is the best move because it maximizes the potential of the rook and creates immediate threats.
# </reasoning>
# <answer>
# Rg2
# </answer><|im_end|>
#
# ================================================================================
# Example 18/30
# ================================================================================
# FEN: 7k/p1r2b2/5q2/1p1p1pR1/5P2/P7/1P2Q2P/1K4R1 w - - 0 32
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# xh5 threatens to recapture with the queen, putting pressure on the white king and potentially opening up the center. It also allows for the immediate development of the queen to f5, which is a strong attacking square. The other moves do not offer as direct or effective threats or develop pieces in a meaningful way.
# </reasoning>
# <answer>
# Bxh5
# </answer><|im_end|>
#
# ================================================================================
# Example 19/30
# ================================================================================
# FEN: rnbqkbnr/ppp2ppp/4p3/3p4/3PP3/8/PPPN1PPP/R1BQKBNR b KQkq - 1 3
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# c6 is a solid development move that advances the center pawns and prepares to open files for the queen. It also prevents White from easily recapturing on c5 with their queen. Other moves like Nc6 or Bb7 are either slower or less direct in developing the board. c6 is therefore the best move as it creates immediate pressure and positional advantage.
# </reasoning>
# <answer>
# c6
# </answer><|im_end|>
#
# ================================================================================
# Example 20/30
# ================================================================================
# FEN: r3k2r/1b3ppp/p3p3/7n/Pp6/3BqN1P/1PP2PP1/R4RK1 w kq - 0 21
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# xe3 captures an important piece (the knight) and prepares for a potential recapture with the queen, maintaining pressure on Black's position. It also opens up possibilities for developing other pieces and controlling the center. Other moves like Qxd5 or exd5 capture less valuable pieces or do not provide immediate tactical advantages.
# </reasoning>
# <answer>
# xe3
# </answer><|im_end|>
#
# ================================================================================
# Example 21/30
# ================================================================================
# FEN: r3k2r/1b3ppp/pq2p3/2b4n/Pp6/3BBN1P/1PP1QPP1/R4RK1 b kq - 4 19
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# g3 is a standard recapture of the queen by the knight, ensuring that White regains material while also developing the knight on a useful square. It's a safe and practical move.
#
# Ng3 is more aggressive, pushing the knight to f5 where it can challenge Black's pawns and disrupt their structure. This move aims to create pressure on Black's kingside and open up possibilities for a quick attack.
#
# While both moves have merits, Ng3 offers more immediate threats and positional advantages. It forces Black to make decisions about how to respond to the knight's advance, potentially leading to weaknesses in
#
# ================================================================================
# Example 22/30
# ================================================================================
# FEN: r1b4k/pp2b1pB/4p3/3pn3/7q/P4P2/1PQB3P/1K1R3R w - - 3 20
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# f4 is the only candidate move provided, so there's no need for comparative analysis. However, if we were to consider other typical moves from this position, they might involve developing pieces or controlling key squares. Since f4 is the sole option given, we'll focus on justifying why it is the best move.
#
# f4 is the best move because it develops a piece (the queen) to a strong square (f4), controlling the center and preparing for further development. It also threatens to recapture with the queen, putting pressure on Black's position.
# </reasoning>
# <answer>
#
#
# ================================================================================
# Example 23/30
# ================================================================================
# FEN: r1b3k1/pp1nb1pp/1qn1p3/3pP3/3P4/P2B1P2/1PQBN2P/R3K2R b KQ - 0 15
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# h4 threatens Bxd7, forcing White to recapture with Qxg4, which weakens their queen and gives Black counterplay on the kingside. However, Bh4+ also threatens Bxd7, but more subtly. It prepares for Nc6 later, developing a piece and creating pressure on g5. Additionally, Bh4+ forces White to recapture with Qxg4, which then leads to a forced sacrifice, giving Black an advantage.
#
# Therefore, Bh4+ is objectively the best move because it creates immediate threats, develops a piece, and sets up a
#
# ================================================================================
# Example 24/30
# ================================================================================
# FEN: r1b1kb1r/5ppp/p2qpn2/1p6/8/3B1N2/PPP2PPP/R1BQ1RK1 b kq - 1 12
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# b4 weakens White's pawn structure on the kingside and puts pressure on the e5 square. It also prepares for Qb3, which could be a strong move later in the game.
#
# 4...Nbd7 is a standard response to Bb4, developing a piece while controlling the center. It doesn't weaken Black's position and prepares to support the attack on the kingside if needed.
#
# 4...a6 is a safe move that develops a minor piece without putting pressure on White's position. However, it doesn't contribute significantly to the development of White's pieces or create
#
# ================================================================================
# Example 25/30
# ================================================================================
# FEN: rnbqkb1r/pppn1ppp/4p3/3pP3/3P4/8/PPPN1PPP/R1BQKBNR w KQkq - 1 5
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# c3 weakens White's pawn structure by pushing away the knight from e2, potentially allowing Black to recapture with better pieces later.
# In contrast, 3...Nc6 is a solid development, placing a knight on a strong square and improving the overall structure of White's position.
# </reasoning>
# <answer>
# 3...Nc6
# </answer><|im_end|>
#
# ================================================================================
# Example 26/30
# ================================================================================
# FEN: 2r4k/p4bR1/4pq2/1p1p1n2/5P2/P2B4/1P2Q2P/1K4R1 w - - 1 30
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# Rxg7 takes out a critical piece and puts pressure on White's king, leading to potential threats to White's position. Qxg7 would be weaker as it fails to capture the rook effectively and leaves Black with an open file.
# </reasoning>
# <answer>
# Rxg7
# </answer><|im_end|>
#
# ================================================================================
# Example 27/30
# ================================================================================
# FEN: r1b1kb1r/5ppp/p2qpn2/1p6/2B5/5N2/PPP2PPP/R1BQ1RK1 w kq - 0 12
# Color: White
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# e1 is a typo and does not represent a valid move in chess. The correct move to consider is e1=Q, which recaptures the knight on f3 with a queen. This move is strong because it recaptures an important piece and puts pressure on the opponent's king.
#
# No other moves were provided, so we cannot compare them. Therefore, e1=Q is the best move available based on the given options.
# </reasoning>
# <answer>
# e1=Q
# </answer><|im_end|>
#
# ================================================================================
# Example 28/30
# ================================================================================
# FEN: r1b2rk1/pp1nb1pp/1qn1p3/3pP3/3P4/P2B1N2/1PQBN1PP/R3K2R b KQ - 2 14
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# h4 threatens Bxd7, forcing White to recapture with Qxg4, which weakens their queen and gives Black counterplay on the kingside. However, Bh4+ also threatens Bxd7, but more subtly. It prepares for Nc6 later, developing a piece and creating pressure on g5. Additionally, Bh4+ forces White to recapture with Qxg4, which then leads to a forced sacrifice, giving Black an advantage.
#
# Therefore, Bh4+ is objectively the best move because it creates immediate threats, develops a piece, and sets up a
#
# ================================================================================
# Example 29/30
# ================================================================================
# FEN: r1b1kb1r/pp3ppp/3qpn2/8/2BN4/8/PPP2PPP/R1BQ1RK1 b kq - 0 10
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# b4 weakens White's pawn structure on the kingside and puts pressure on the e5 square. It also prepares for Qb3, which could be a strong move later in the game.
#
# 4...Nbd7 is a standard response to Bb4, developing a piece while controlling the center. It doesn't weaken Black's position and prepares to support the attack on the kingside if needed.
#
# 4...a6 is a safe move that develops a minor piece without putting pressure on White's position. However, it doesn't contribute significantly to the development of White's pieces or create
#
# ================================================================================
# Example 30/30
# ================================================================================
# FEN: r1b1kb1r/1p3ppp/p2qpn2/8/2B5/5N2/PPP2PPP/R1BQ1RK1 b kq - 1 11
# Color: Black
#
# Generated Answer:
# <think>
#
# </think>
#
# <reasoning>
# c5 is a strong move that attacks the white queen and threatens to recapture on e4. It also puts pressure on the white king's position. However, it sacrifices the knight, which could be considered weak if White manages to defend well.
#
# Bc5 is a more balanced move. It develops the bishop to a strong square and prepares to support the queen on the kingside. This move maintains development while controlling key squares on both wings.
#
# Therefore, Bc5 is objectively the best move because it combines effective piece development with tactical threats, providing a stronger overall position for Black.
# </reason
#
# === SCORE TABLE (top 10 rows) ===
#     idx     Move  InTop5  EqualsBest  HasReasoningTag  HasAnswerTag  Score
# 0     3      O-O    True       False             True          True      5
# 1    11      Bc3    True       False             True          True      5
# 2    10       c6    True       False             True          True      5
# 3    16      Rg2    True       False             True          True      5
# 4     1      Ne2   False       False             True          True      3
# 5     2       g8   False       False             True          True      3
# 6     5       d7   False       False             True          True      3
# 7     4      Kb1   False       False             True          True      3
# 8     6       g8   False       False             True          True      3
# 9     7     Nxd4   False       False             True          True      3
# 10   13       e8   False       False             True          True      3
# 11    9     Nxd4   False       False             True          True      3
# 12   15       a5   False       False             True          True      3
# 13    0      Rg2   False       False             True          True      3
# 14   19      xe3   False       False             True          True      3
# 15   26     e1=Q   False       False             True          True      3
# 16   17     Bxh5   False       False             True          True      3
# 17   18       c6   False       False             True          True      3
# 18   24  3...Nc6   False       False             True          True      3
# 19   25     Rxg7   False       False             True          True      3
# 20   21            False       False             True         False      1
# 21   12            False       False             True         False      1
# 22    8            False       False            False         False      0
# 23   14            False       False            False         False      0
# 24   20            False       False            False         False      0
# 25   23            False       False            False         False      0
# 26   22            False       False            False         False      0
# 27   27            False       False            False         False      0
# 28   28            False       False            False         False      0
# 29   29            False       False            False         False      0

# %%
import chess
import pandas as pd

# simple legality check
def is_legal_move(fen, san):
    try:
        board = chess.Board(fen)
        move = board.parse_san(san)  # will raise error if move invalid
        return move in board.legal_moves
    except Exception:
        return False
before_df = pd.read_csv("sft_answer_scoring_before_training.csv")
before_df["is_legal"] = before_df.apply(lambda x: is_legal_move(x["FEN"], x["Move"]), axis=1)
after_df = pd.read_csv("sft_answer_scoring_after_training.csv")
after_df["is_legal"] = after_df.apply(lambda x: is_legal_move(x["FEN"], x["Move"]), axis=1)
legal_count = before_df["is_legal"].sum()
print("Number of legal moves:", legal_count)
legal_count = after_df["is_legal"].sum()
print("Number of legal moves:", legal_count)
# Out:
# Number of legal moves: 0
# Number of legal moves: 8
